# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.7.2'

# %%
pd.__version__
# Out:
# '2.0.3'

# %%
# !pip install --upgrade matplotlib --user

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df=pd.read_csv("smartphone_cleaned_v5.csv")

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  \
# 0           False      snapdragon        8.0              3.2
# 1           False      snapdragon        8.0              2.2
# 2           False          exynos        8.0              2.4
# 3           False      snapdragon        8.0              2.2
# 4           False       dimensity        8.0              2.6
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            5000.0                        1          100.0          12.0
# ...

# %%
df.shape
# Out:
# (980, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# resolution                     0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# dtype: int64

# %%
# always have goal in mind why we are doing EDA

# %%
# brand name -> categorical column
# univarient ananlysis in categorical columns

# %%
df["brand_name"].value_counts()
# Out:
# brand_name
# xiaomi       134
# samsung      132
# vivo         111
# realme        97
# oppo          88
# motorola      52
# apple         46
# oneplus       42
# poco          41
# tecno         33
# iqoo          32
# infinix       29
# huawei        16
# google        14
# nokia         13
# honor         13
# itel          10
# sony           9
# asus           7
# nubia          6
# nothing        5
# lava           4
# jio            4
# gionee         3
# micromax       3
# oukitel        3
# lg             3
# redmi          3
# letv           3
# ikall          3
# royole         2
# doogee         2
# zte            2
# lenovo         2
# lyf            2
# sharp          1
# tcl            1
# cat            1
# leitz          1
# duoqin         1
# leeco          1
# blu            1
# vertu          1
# tesla          1
# cola           1
# blackview      1
# Name: count, dtype: int64

# %%
# plot a  graph of top 5 brands 
df["brand_name"].value_counts().head(5).plot(kind="bar")
# Out:
# <Axes: xlabel='brand_name'>

# %%
# plot a  graph of top 10 brands 
df["brand_name"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='brand_name'>

# %%
# pie chart 
df["brand_name"].value_counts().head(10).plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# missing value in brand name 
df["brand_name"].isnull().sum()
# Out:
# 0

# %%
# model
df["model"].nunique()
# here the unique value is 980 we can't consider this column as categorical
# Out:
# 980

# %% [raw]
# # price
# # steps used in unvarient analysis in numerical columns
# 1. find the discription of the columns
# 2.

# %%
df["price"].describe()
# Out:
# count       980.000000
# mean      32520.504082
# std       39531.812669
# min        3499.000000
# 25%       12999.000000
# 50%       19994.500000
# 75%       35491.500000
# max      650000.000000
# Name: price, dtype: float64

# %% [raw]
# # what we find here with describe()
# """
# 1. Distrbution is not normal it has to be squewed
# 2. Some outlier in the data
# 3. There is huge difference in mean and median
# 4. normally 32520 is the average of the price of phone which is kinda weired things
#
# """

# %%
#sns.displot(kind="hist",data=df,x="price")
#sns.kdeplot(data=tips, x="total_bill")
sns.kdeplot(data=df,x="price")
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.displot(data=df,x="price",kind="hist",kde=True)
# Out:
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
sns.kdeplot(data=df,x=df["price"])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
tips = sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill")
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.displot(data=df,x="price",kind="hist",kde=True)
# Out:
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
# more phones on less price side 
# very less phones on the higher price
# it is highly skew data

# %%
df["price"].skew()
# Out:
# 6.591790999665567

# %%
sns.boxplot(df["price"])
# few outliers are there
# Out:
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <Axes: xlabel='price'>

# %%
# rating
df["rating"].describe()
# Out:
# count    879.000000
# mean      78.258248
# std        7.402854
# min       60.000000
# 25%       74.000000
# 50%       80.000000
# 75%       84.000000
# max       89.000000
# Name: rating, dtype: float64

# %%
df["rating"].isnull().sum()
# Out:
# 101

# %%
sns.displot(kind="hist",data=df,x="rating",kde=True)
# Out:
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)

# %%
df["rating"].skew()
# almost closed to 0
# Out:
# -0.6989993034105535

# %%
sns.boxplot(data=df,x="rating")
# Out:
# <Axes: xlabel='rating'>

# %%
df["rating"].isnull().sum()
# huge no. of missing values
# Out:
# 101

# %%
(df["rating"].isnull().sum()/len(df["rating"]))*100
# around 10% data are missing
# Out:
# 10.306122448979592

# %%
# has_5g, has_nfc, has_ir_blaster-> categorical columns 
df["has_5g"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='has_5g'>

# %%
df["has_5g"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# more than 50 %  of phone are having 5g feature (high  price phones )

# %%
df["has_nfc"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
# approx  40% of mobile having nfc faeture which is (high price phones)

# %%
# ir-blaster

# %%
df["has_ir_blaster"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# 16 % of phones having ir_blaster
# Out:
# <Axes: ylabel='count'>

# %%
df[df["has_ir_blaster"]==True]["brand_name"].value_counts()
# ir blaster is more common on xiaomi and poco  phones 
# mostly chinees phone provide the ir_blaster feature
# Out:
# brand_name
# xiaomi     109
# poco        30
# iqoo         6
# huawei       6
# vivo         4
# redmi        2
# honor        1
# samsung      1
# Name: count, dtype: int64

# %%
df[df["has_ir_blaster"]==True]["brand_name"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='brand_name'>

# %%
# processor_brand
df["processor_brand"].value_counts()
# Out:
# processor_brand
# snapdragon    413
# helio         201
# dimensity     177
# exynos         50
# bionic         45
# unisoc         26
# tiger          24
# google          9
# kirin           7
# spreadtrum      4
# sc9863a         2
# fusion          1
# mediatek        1
# Name: count, dtype: int64

# %%
df["processor_brand"].value_counts().plot(kind="pie",autopct="%0.2f%%")
# 43 % by snapdragon
# Out:
# <Axes: ylabel='count'>

# %%
df["processor_brand"].value_counts().head(7).plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging_available', 'fast_charging',
#        'ram_capacity', 'internal_memory', 'screen_size', 'refresh_rate',
#        'resolution', 'num_rear_cameras', 'num_front_cameras', 'os',
#        'primary_camera_rear', 'primary_camera_front',
#        'extended_memory_available', 'extended_upto'],
#       dtype='object')

# %%
df["num_cores"].value_counts().head(7).plot(kind="pie",autopct="%0.2f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["fast_charging_available"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["ram_capacity"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["internal_memory"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["refresh_rate"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["refresh_rate"].value_counts()
# Out:
# refresh_rate
# 60     368
# 120    344
# 90     219
# 144     39
# 165      9
# 240      1
# Name: count, dtype: int64

# %%
(df["num_rear_cameras"]+df["num_front_cameras"]).value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["os"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["extended_memory_available"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["extended_memory_available"].value_counts()
# Out:
# extended_memory_available
# 1    618
# 0    362
# Name: count, dtype: int64

# %%
df["extended_upto"].value_counts().plot(kind="pie",autopct="%0.1f%%")
# Out:
# <Axes: ylabel='count'>

# %%
df["extended_upto"].value_counts()
# Out:
# extended_upto
# 1024.0    263
# 512.0     116
# 256.0     100
# 128.0       9
# 2048.0      6
# 32.0        3
# 64.0        3
# Name: count, dtype: int64

# %%
def plot_graph(column_name):
    sns.displot(kind="hist",kde=True,data=df,x=column_name,label=column_name)
    sns.catplot(kind="box",data=df,x=column_name)

# %%
df.select_dtypes(include=["float64","int64"]).iloc[:,[3,4,6,9,13,14,16]].head()
# selecting numerical columns
# Out:
#    processor_speed  battery_capacity  fast_charging  screen_size  \
# 0              3.2            5000.0          100.0         6.70
# 1              2.2            5000.0           33.0         6.59
# 2              2.4            5000.0           15.0         6.60
# 3              2.2            5000.0            NaN         6.55
# 4              2.6            5000.0           67.0         6.70
#
#    primary_camera_rear  primary_camera_front  extended_upto
# 0                 50.0                  16.0            NaN
# 1                 64.0                  16.0         1024.0
# 2                 50.0                  13.0         1024.0
# 3                 50.0                  16.0         1024.0
# 4                108.0                  16.0            NaN

# %%
num_columns =df.select_dtypes(include=["float64","int64"]).iloc[:,[3,4,6,9,13,14,16]].columns

# %%
num_columns
# Out:
# Index(['processor_speed', 'battery_capacity', 'fast_charging', 'screen_size',
#        'primary_camera_rear', 'primary_camera_front', 'extended_upto'],
#       dtype='object')

# %%
for i in num_columns:
    plot_graph(i)
# Out:
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)
# C:\Users\91993\anaconda3\lib\site-packages\seaborn\axisgrid.py:64: UserWarning: The figure layout has changed to tight
#   self.fig.tight_layout(*args, **kwargs)
# ...

# %% [markdown]
# #### Bivariennt Analysis

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=df,x="brand_name",y="price")
plt.xticks(rotation='vertical')
plt.show()

# %%
# the brand which has atleat 10 phones

# %%
x=df.groupby("brand_name").count()["model"]

# %%
temp_df=df[df["brand_name"].isin(x[x>10].index)]

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=temp_df,x="brand_name",y="price")
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  \
# 0           False      snapdragon        8.0              3.2
# 1           False      snapdragon        8.0              2.2
# 2           False          exynos        8.0              2.4
# 3           False      snapdragon        8.0              2.2
# 4           False       dimensity        8.0              2.6
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            5000.0                        1          100.0          12.0
# ...

# %%
sns.scatterplot(data=df,x="rating",y="price")
# Out:
# <Axes: xlabel='rating', ylabel='price'>

# %%
sns.barplot(data=temp_df,x="has_5g",y="price",estimator=np.median)
# Out:
# <Axes: xlabel='has_5g', ylabel='price'>

# %%
sns.barplot(data=temp_df,x="has_nfc",y="price",estimator=np.median)
# Out:
# <Axes: xlabel='has_nfc', ylabel='price'>

# %%
sns.pointplot(data=temp_df,x="has_nfc",y="price",estimator=np.median)
# Out:
# <Axes: xlabel='has_nfc', ylabel='price'>

# %%
sns.barplot(data=temp_df,x="has_ir_blaster",y="price",estimator=np.median)
# Out:
# <Axes: xlabel='has_ir_blaster', ylabel='price'>

# %%
sns.pointplot(data=temp_df,x="has_ir_blaster",y="price",estimator=np.median)
# Out:
# <Axes: xlabel='has_ir_blaster', ylabel='price'>

# %%
sns.barplot(data=temp_df,x="processor_brand",y="price",estimator=np.median)
plt.xticks(rotation="vertical")
plt.show()

# %%
sns.barplot(data=temp_df,x="num_cores",y="price",estimator=np.median)
# Out:
# <Axes: xlabel='num_cores', ylabel='price'>

# %%
pd.crosstab(df["num_cores"],df["os"])
# all the ios is 6.0 core thats why price is high
# Out:
# os         android  ios  other
# num_cores
# 4.0             33    1      1
# 6.0              0   39      0
# 8.0            875    1     10

# %%
sns.scatterplot(data=df,x="processor_speed",y="price")
# Out:
# <Axes: xlabel='processor_speed', ylabel='price'>

# %%
sns.scatterplot(data=df,x="screen_size",y="price")
# Out:
# <Axes: xlabel='screen_size', ylabel='price'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only =True))
# Out:
# <Axes: >

# %%
df.corr(numeric_only =True)["price"]
# Out:
# price                        1.000000
# rating                       0.283504
# has_5g                       0.305066
# has_nfc                      0.470951
# has_ir_blaster              -0.015807
# num_cores                   -0.048561
# processor_speed              0.474049
# battery_capacity            -0.159232
# fast_charging_available      0.116739
# fast_charging                0.277591
# ram_capacity                 0.386002
# internal_memory              0.557168
# screen_size                  0.113253
# refresh_rate                 0.244115
# num_rear_cameras             0.125330
# num_front_cameras            0.115228
# primary_camera_rear          0.092095
# primary_camera_front         0.162995
# extended_memory_available   -0.448628
# extended_upto                0.091945
# Name: price, dtype: float64

# %%
df.isnull().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# resolution                     0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# dtype: int64

# %%
df.corr(numeric_only =True)["rating"]
# Out:
# price                        0.283504
# rating                       1.000000
# has_5g                       0.596087
# has_nfc                      0.474754
# has_ir_blaster               0.156421
# num_cores                    0.199741
# processor_speed              0.628446
# battery_capacity            -0.015581
# fast_charging_available      0.542814
# fast_charging                0.527613
# ram_capacity                 0.757613
# internal_memory              0.481070
# screen_size                  0.298272
# refresh_rate                 0.610795
# num_rear_cameras             0.515531
# num_front_cameras            0.131480
# primary_camera_rear          0.562046
# primary_camera_front         0.577861
# extended_memory_available   -0.415265
# extended_upto                0.346761
# Name: rating, dtype: float64

# %%
# knn imputer

# %%
df.shape
# Out:
# (980, 25)

# %%
df.select_dtypes(include=["float64","int64"])
# Out:
#       price  rating  num_cores  processor_speed  battery_capacity  \
# 0     54999    89.0        8.0             3.20            5000.0
# 1     19989    81.0        8.0             2.20            5000.0
# 2     16499    75.0        8.0             2.40            5000.0
# 3     14999    81.0        8.0             2.20            5000.0
# 4     24999    82.0        8.0             2.60            5000.0
# 5     16999    80.0        8.0             2.20            5000.0
# 6     65999    81.0        6.0             3.22            3279.0
# 7     29999    86.0        8.0             2.60            4980.0
# 8     26749    85.0        8.0             2.50            4500.0
# 9     28999    84.0        8.0             3.00            4500.0
# 10    18999    82.0        8.0             2.20            5000.0
# 11    18999    79.0        8.0             2.20            5000.0
# 12    24762    79.0        8.0             2.60            5000.0
# ...

# %%
df.select_dtypes(include=["float64","int64"]).head()
# Out:
#    price  rating  num_cores  processor_speed  battery_capacity  \
# 0  54999    89.0        8.0              3.2            5000.0
# 1  19989    81.0        8.0              2.2            5000.0
# 2  16499    75.0        8.0              2.4            5000.0
# 3  14999    81.0        8.0              2.2            5000.0
# 4  24999    82.0        8.0              2.6            5000.0
#
#    fast_charging_available  fast_charging  ram_capacity  internal_memory  \
# 0                        1          100.0          12.0            256.0
# 1                        1           33.0           6.0            128.0
# 2                        1           15.0           4.0             64.0
# 3                        1            NaN           6.0            128.0
# 4                        1           67.0           6.0            128.0
#
#    screen_size  refresh_rate  num_rear_cameras  num_front_cameras  \
# 0         6.70           120                 3                1.0
# ...

# %%
x_df=df.select_dtypes(include=["float64","int64"]).drop(columns="price")

# %%
# import knn imputer

# %%
from sklearn.impute import KNNImputer

# %%
imputer=KNNImputer(n_neighbors=5)

# %%
x_df_values=imputer.fit_transform(x_df)

# %%
pd.DataFrame(x_df_values,columns=x_df.columns)
# Out:
#      rating  num_cores  processor_speed  battery_capacity  \
# 0      89.0        8.0            3.200            5000.0
# 1      81.0        8.0            2.200            5000.0
# 2      75.0        8.0            2.400            5000.0
# 3      81.0        8.0            2.200            5000.0
# 4      82.0        8.0            2.600            5000.0
# 5      80.0        8.0            2.200            5000.0
# 6      81.0        6.0            3.220            3279.0
# 7      86.0        8.0            2.600            4980.0
# 8      85.0        8.0            2.500            4500.0
# 9      84.0        8.0            3.000            4500.0
# 10     82.0        8.0            2.200            5000.0
# 11     79.0        8.0            2.200            5000.0
# 12     79.0        8.0            2.600            5000.0
# 13     80.0        8.0            2.200            5000.0
# 14     86.4        8.0            3.200            5000.0
# ...

# %%
x_df=pd.DataFrame(x_df_values,columns=x_df.columns)

# %%
x_df["price"]=df["price"]

# %%
x_df.head()
# Out:
#    rating  num_cores  processor_speed  battery_capacity  \
# 0    89.0        8.0              3.2            5000.0
# 1    81.0        8.0              2.2            5000.0
# 2    75.0        8.0              2.4            5000.0
# 3    81.0        8.0              2.2            5000.0
# 4    82.0        8.0              2.6            5000.0
#
#    fast_charging_available  fast_charging  ram_capacity  internal_memory  \
# 0                      1.0          100.0          12.0            256.0
# 1                      1.0           33.0           6.0            128.0
# 2                      1.0           15.0           4.0             64.0
# 3                      1.0           29.2           6.0            128.0
# 4                      1.0           67.0           6.0            128.0
#
#    screen_size  refresh_rate  num_rear_cameras  num_front_cameras  \
# 0         6.70         120.0               3.0                1.0
# ...

# %%
a=x_df.corr()["price"].reset_index()

# %%
b=df.corr(numeric_only =True)["price"].reset_index()

# %%
b.merge(a,on="index")
# Out:
#                         index   price_x   price_y
# 0                       price  1.000000  1.000000
# 1                      rating  0.283504  0.341727
# 2                   num_cores -0.048561 -0.055949
# 3             processor_speed  0.474049  0.488426
# 4            battery_capacity -0.159232 -0.166257
# 5     fast_charging_available  0.116739  0.116739
# 6               fast_charging  0.277591  0.220688
# 7                ram_capacity  0.386002  0.386002
# 8             internal_memory  0.557168  0.557168
# 9                 screen_size  0.113253  0.113253
# 10               refresh_rate  0.244115  0.244115
# 11           num_rear_cameras  0.125330  0.125330
# 12          num_front_cameras  0.115228  0.115787
# 13        primary_camera_rear  0.092095  0.092095
# 14       primary_camera_front  0.162995  0.160281
# 15  extended_memory_available -0.448628 -0.448628
# 16              extended_upto  0.091945 -0.004073

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  \
# 0           False      snapdragon        8.0              3.2
# 1           False      snapdragon        8.0              2.2
# 2           False          exynos        8.0              2.4
# 3           False      snapdragon        8.0              2.2
# 4           False       dimensity        8.0              2.6
#
#    battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# 0            5000.0                        1          100.0          12.0
# ...

# %%
pd.get_dummies(df,columns=["brand_name","processor_brand","os"],drop_first=True).head()
# Out:
#                        model  price  rating  has_5g  has_nfc  has_ir_blaster  \
# 0              OnePlus 11 5G  54999    89.0    True     True           False
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False           False
# 2      Samsung Galaxy A14 5G  16499    75.0    True    False           False
# 3       Motorola Moto G62 5G  14999    81.0    True    False           False
# 4         Realme 10 Pro Plus  24999    82.0    True    False           False
#
#    num_cores  processor_speed  battery_capacity  fast_charging_available  \
# 0        8.0              3.2            5000.0                        1
# 1        8.0              2.2            5000.0                        1
# 2        8.0              2.4            5000.0                        1
# 3        8.0              2.2            5000.0                        1
# 4        8.0              2.6            5000.0                        1
#
# ...

# %%
pd.get_dummies(df,columns=["brand_name","processor_brand","os"],drop_first=True).head().shape
# Out:
# (5, 81)

# %%
pd.get_dummies(df,columns=["brand_name","processor_brand","os"],drop_first=True).head().fillna(0)
# Out:
#                        model  price  rating  has_5g  has_nfc  has_ir_blaster  \
# 0              OnePlus 11 5G  54999    89.0    True     True           False
# 1  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False           False
# 2      Samsung Galaxy A14 5G  16499    75.0    True    False           False
# 3       Motorola Moto G62 5G  14999    81.0    True    False           False
# 4         Realme 10 Pro Plus  24999    82.0    True    False           False
#
#    num_cores  processor_speed  battery_capacity  fast_charging_available  \
# 0        8.0              3.2            5000.0                        1
# 1        8.0              2.2            5000.0                        1
# 2        8.0              2.4            5000.0                        1
# 3        8.0              2.2            5000.0                        1
# 4        8.0              2.6            5000.0                        1
#
# ...
